# %%
chinese = 78
english = 93
math = 73

total = chinese + english + math
print("total=", total)
# Out:
# total= 244

# %%
# 字串的相加
"total=" + "100"
"=" * 60
# Out:
# '============================================================'

# %%
# 字串和變數的整合
apple = 5
orange = 9

print("蘋果=" + str(apple) + "個,橘子=" + str(orange) + "個")
# Out:
# '蘋果=5個,橘子=9個'

# %%
# str template
# 字串插補變數
# 字串和變數整合,傳出1個全新的字串
print(f"蘋果={apple}個,橘子={orange}個")
# Out:
# 蘋果=5個,橘子=9個
